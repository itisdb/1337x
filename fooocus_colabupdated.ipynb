# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/mustbehidryde/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 70.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.0
#     Uninstalling pygit2-1.19.0:
#       Successfully uninstalled pygit2-1.19.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6609, done.
# remote: Total 6609 (delta 0), reused 0 (delta 0), pack-reused 6609 (from 1)
# Receiving objects: 100% (6609/6609), 33.29 MiB | 23.70 MiB/s, done.
# Resolving deltas: 100% (3765/3765), done.
# /content/Fooocus

# %%
# @title Select Account Type
is_pro = True # @param {type:"boolean"}

print(f"Account type selected: {'Pro' if is_pro else 'Non-Pro'} (is_pro = {is_pro})")

if is_pro:
  from google.colab import drive
  drive.mount('/content/gdrive')
  # !ln -s /content/gdrive/MyDrive/1TB/checkpoints/* /content/Fooocus/models/checkpoints/
else:
  # %cd /content/Fooocus/models/checkpoints/
  # Arthemy Comics XL
  # !wget https://civitai.com/api/download/models/1019183?type=Model&format=SafeTensor&size=pruned&fp=fp16
  #Arthemy Real XL
  # !wget https://civitai.com/api/download/models/631520?type=Model&format=SafeTensor&size=pruned&fp=fp16
  #Arthemy Comics 1.5 (as a refiner)
  # !wget https://civitai.com/api/download/models/830649?type=Model&format=SafeTensor&size=pruned&fp=fp16
  #Arthemy Real 1.5 (as a refiner)
  https://civitai.com/api/download/models/271398?type=Model&format=SafeTensor&size=pruned&fp=fp16
  # Juggernaut
  # !wget https://civitai.com/api/download/models/1759168?type=Model&format=SafeTensor&size=full&fp=fp16
  # Rename Juggernaut
  # %mv juggernautXL_ragnarokBy.safetensors juggernautXL_v8Rundiffusion.safetensors
  # %cd -
# Out:
# Account type selected: Pro (is_pro = True)

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://civitai.com/api/download/models/341068?type=Model&format=SafeTensor" to /content/Fooocus/models/loras/NSFWXL.safetensor
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 145, in <module>
#     config.default_base_model_name, config.checkpoint_downloads = download_models(
#                                                                   ^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/launch.py", line 138, in download_models
#     load_file_from_url(url=url, model_dir=model_dir, file_name=file_name)
# ...
